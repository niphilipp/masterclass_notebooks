# %% [markdown]
# # Dataset Cortez_cardoso
# ##

# %%
# import all needed R packages
library(ChAMP)
library(ChAMPdata)
library(ggplot2)
library(stringr)
library(ggpubr)
library(RColorBrewer)
library(colorspace)
library(tidyr)
library(tibble)
library(dplyr)
library(IlluminaHumanMethylationEPICanno.ilm10b4.hg19)
source("/home/jovyan/notebooks/scripts/custom_functions.R")
print("All libraries successfully loaded")
# Out:
# Loading required package: minfi
#
# Loading required package: BiocGenerics
#
# Loading required package: generics
#
#
# Attaching package: ‘generics’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: Seqinfo
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: bumphunter
#
# Loading required package: foreach
#
# Loading required package: iterators
#
# Loading required package: parallel
#
# Loading required package: locfit
#
# locfit 1.5-9.12 	 2025-03-05
#
# Setting options('download.file.method.GEOquery'='auto')
#
# Setting options('GEOquery.inmemory.gpl'=FALSE)
#
# Loading required package: ChAMPdata
#
# Loading required package: DMRcate
#
#
#
# Loading required package: Illumina450ProbeVariants.db
#
# Loading required package: IlluminaHumanMethylationEPICmanifest
#
# Loading required package: DT
#
# Loading required package: RPMM
#
# Loading required package: cluster
#
# No methods found in package 'RSQLite' for request: 'dbListFields' when loading 'lumi'
#
# Warning message:
# "replacing previous import 'plyr::mutate' by 'plotly::mutate' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'plyr::rename' by 'plotly::rename' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'plyr::arrange' by 'plotly::arrange' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'plyr::summarise' by 'plotly::summarise' when loading 'ChAMP'"
#
#
# Warning message:
# "replacing previous import 'plotly::subplot' by 'Hmisc::subplot' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'plyr::summarize' by 'Hmisc::summarize' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'plyr::is.discrete' by 'Hmisc::is.discrete' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'plotly::last_plot' by 'ggplot2::last_plot' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'globaltest::model.matrix' by 'stats::model.matrix' when loading 'ChAMP'"
# Warning message:
# "replacing previous import 'globaltest::p.adjust' by 'stats::p.adjust' when loading 'ChAMP'"
# >> Package version 2.29.1 loaded <<
#        ___ _      _   __  __ ___
#       / __| |_   /_\ |  \/  | _ \
#      | (__| ' \ / _ \| |\/| |  _/
#       \___|_||_/_/ \_\_|  |_|_|
#       ------------------------------
#     If you have any question or suggestion about ChAMP, please email to champ450k@gmail.com.
#     Thank you for citating ChAMP:
#
#     Yuan Tian, Tiffany J Morris, Amy P Webster, Zhen Yang, Stephan Beck, Andrew Feber, Andrew E Teschendorff; ChAMP: updated methylation analysis pipeline for Illumina BeadChips, Bioinformatics, btx513, https://doi.org/10.1093/bioinformatics/btx513    REQUIRE ChAMPdata >= 2.23.1
#
#
# Attaching package: 'tidyr'
#
#
# The following object is masked from 'package:S4Vectors':
#
#     expand
#
#
#
# Attaching package: 'dplyr'
#
#
# The following object is masked from 'package:minfi':
#
#     combine
#
#
# The following objects are masked from 'package:Biostrings':
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from 'package:XVector':
#
#     slice
#
#
# The following object is masked from 'package:Biobase':
#
#     combine
#
#
# The following object is masked from 'package:matrixStats':
#
#     count
#
#
# The following objects are masked from 'package:GenomicRanges':
#
#     intersect, setdiff, union
#
#
# The following object is masked from 'package:Seqinfo':
#
#     intersect
#
#
# The following objects are masked from 'package:IRanges':
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from 'package:S4Vectors':
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from 'package:BiocGenerics':
#
#     combine, intersect, setdiff, setequal, union
#
#
# The following object is masked from 'package:generics':
#
#     explain
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# [1] "All libraries successfully loaded"

# %%
# set the location of the data directory
# the .idat fluorescence files and the samplesheet.csv have to be located inside the directory and it's subdirectories
getwd()
data_dir <- "/home/jovyan/datasets/Cortez_cardoso"
print("Dataset directory successfully set")
# Out:
# [1] "/home/jovyan/notebooks/Cortez_Cardoso"
# [1] "Dataset directory successfully set"

# %%
# Load in the data
myLoad <- champ.load(directory = data_dir,
                     method="ChAMP", # replaces old loading method using minfi
                     methValue="B", # wether to calculate beta- or M-values
                     autoimpute=TRUE, # if values are missing uses the 3 most similar probes and uses the mean of their values for the missing value 
                     filterDetP=TRUE, # filter single probes, whose methylation signal vs the background signal of the slide is not significant (detPcut)
                     ProbeCutoff=0, # remove all probes with higher missing-value-ratio
                     SampleCutoff=0.1, # remove a full sample if the failed probe ratio (based on p value) is higher
                     detPcut=0.01, # significance p-value cutoff for filterDetP
                     filterBeads=TRUE, # filter out probes if the fraction of samples with a beadcount < 3 is higher than beadCutoff
                     beadCutoff=0.05, # acceptable fraction of samples with a beadcount < 3
                     filterNoCG=TRUE, # wether to remove non-cg probes
                     filterSNPs=TRUE, # wether to remove probes that fallnear a SNP (as defined in Nordlund et al. https://link.springer.com/article/10.1186/s13059-021-02529-2) 
                     population=NULL, # can be assigned to specific population according to www.internationalgenome.org/category/population/
                     filterMultiHit=TRUE, # wether to remove probes that align to multiple genomic locations (also according to Nordlund et al.)
                     filterXY=TRUE, # wether to remove probes on x and y chromosomes
                     force=FALSE, # minfi specific parameter
                     arraytype="EPICv1") # microarray type (can be one of "450K" "EPICv1" or "EPICv2") 

champ.QC(beta = myLoad$beta, # beta values stored in champ.load output
         pheno=myLoad$pd$Sample_Group, # what samplesheet column is your phenotype (where do u expect the major difference between your samples)?
         resultsDir="./CHAMP_QCimages/") # the plots will be saved in the directory this notebook file is located in
# Out:
# [===========================]
#
# [<<<< ChAMP.LOAD START >>>>>]
#
# -----------------------------
#
#
# [ Loading Data with ChAMP Method ]
#
# ----------------------------------
#
# Note that ChAMP method will NOT return rgSet or mset, they object defined by minfi. Which means, if you use ChAMP method to load data, you can not use SWAN or FunctionNormliazation method in champ.norm() (you can use BMIQ or PBC still). But All other function should not be influenced.
#
#
# [===========================]
#
# [<<<< ChAMP.IMPORT START >>>>>]
#
# -----------------------------
#
#
# [ Section 1: Read PD Files Start ]
#
#   CSV Directory: /home/jovyan/datasets/Cortez_cardoso/Samplesheet.csv
#
#   Find CSV Success
#
#   Reading CSV File
#
#   Replace Sentrix_Position into Array
#
#   Replace Sentrix_ID into Slide
#
#   There is NO Pool_ID in your pd file.
#
# [ Section 1: Read PD file Done ]
#
#
#
# [ Section 2: Read IDAT files Start ]
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307505_206402350014_R01C01_Grn.idat.gz ---- (1/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307507_206402350014_R03C01_Grn.idat.gz ---- (2/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307513_206402350066_R01C01_Grn.idat.gz ---- (3/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307520_206402350066_R08C01_Grn.idat.gz ---- (4/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307521_206402350102_R01C01_Grn.idat.gz ---- (5/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307523_206402350102_R03C01_Grn.idat.gz ---- (6/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307528_206402350102_R08C01_Grn.idat.gz ---- (7/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307533_206402350127_R05C01_Grn.idat.gz ---- (8/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307541_206402350128_R05C01_Grn.idat.gz ---- (9/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307543_206402350128_R07C01_Grn.idat.gz ---- (10/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307506_206402350014_R02C01_Grn.idat.gz ---- (11/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307508_206402350014_R04C01_Grn.idat.gz ---- (12/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307511_206402350014_R07C01_Grn.idat.gz ---- (13/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307514_206402350066_R02C01_Grn.idat.gz ---- (14/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307529_206402350127_R01C01_Grn.idat.gz ---- (15/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307530_206402350127_R02C01_Grn.idat.gz ---- (16/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307531_206402350127_R03C01_Grn.idat.gz ---- (17/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307534_206402350127_R06C01_Grn.idat.gz ---- (18/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307536_206402350127_R08C01_Grn.idat.gz ---- (19/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307547_206402350151_R03C01_Grn.idat.gz ---- (20/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307509_206402350014_R05C01_Grn.idat.gz ---- (21/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307515_206402350066_R03C01_Grn.idat.gz ---- (22/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307516_206402350066_R04C01_Grn.idat.gz ---- (23/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307518_206402350066_R06C01_Grn.idat.gz ---- (24/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307526_206402350102_R06C01_Grn.idat.gz ---- (25/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307553_206402350152_R01C01_Grn.idat.gz ---- (26/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307558_206402350152_R06C01_Grn.idat.gz ---- (27/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307569_206402350156_R01C01_Grn.idat.gz ---- (28/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307572_206402350156_R04C01_Grn.idat.gz ---- (29/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307581_206402350158_R05C01_Grn.idat.gz ---- (30/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307584_206402350158_R08C01_Grn.idat.gz ---- (31/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307586_206402350163_R02C01_Grn.idat.gz ---- (32/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307597_206402350177_R05C01_Grn.idat.gz ---- (33/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307613_206419180144_R02C01_Grn.idat.gz ---- (34/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307618_206419180144_R07C01_Grn.idat.gz ---- (35/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307594_206402350177_R02C01_Grn.idat.gz ---- (36/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307587_206402350163_R03C01_Grn.idat.gz ---- (37/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307570_206402350156_R02C01_Grn.idat.gz ---- (38/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307505_206402350014_R01C01_Red.idat.gz ---- (1/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307507_206402350014_R03C01_Red.idat.gz ---- (2/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307513_206402350066_R01C01_Red.idat.gz ---- (3/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307520_206402350066_R08C01_Red.idat.gz ---- (4/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307521_206402350102_R01C01_Red.idat.gz ---- (5/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307523_206402350102_R03C01_Red.idat.gz ---- (6/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307528_206402350102_R08C01_Red.idat.gz ---- (7/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307533_206402350127_R05C01_Red.idat.gz ---- (8/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307541_206402350128_R05C01_Red.idat.gz ---- (9/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307543_206402350128_R07C01_Red.idat.gz ---- (10/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307506_206402350014_R02C01_Red.idat.gz ---- (11/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307508_206402350014_R04C01_Red.idat.gz ---- (12/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307511_206402350014_R07C01_Red.idat.gz ---- (13/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307514_206402350066_R02C01_Red.idat.gz ---- (14/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307529_206402350127_R01C01_Red.idat.gz ---- (15/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307530_206402350127_R02C01_Red.idat.gz ---- (16/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307531_206402350127_R03C01_Red.idat.gz ---- (17/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307534_206402350127_R06C01_Red.idat.gz ---- (18/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307536_206402350127_R08C01_Red.idat.gz ---- (19/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307547_206402350151_R03C01_Red.idat.gz ---- (20/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307509_206402350014_R05C01_Red.idat.gz ---- (21/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307515_206402350066_R03C01_Red.idat.gz ---- (22/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307516_206402350066_R04C01_Red.idat.gz ---- (23/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307518_206402350066_R06C01_Red.idat.gz ---- (24/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307526_206402350102_R06C01_Red.idat.gz ---- (25/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307553_206402350152_R01C01_Red.idat.gz ---- (26/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307558_206402350152_R06C01_Red.idat.gz ---- (27/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307569_206402350156_R01C01_Red.idat.gz ---- (28/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307572_206402350156_R04C01_Red.idat.gz ---- (29/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307581_206402350158_R05C01_Red.idat.gz ---- (30/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307584_206402350158_R08C01_Red.idat.gz ---- (31/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307586_206402350163_R02C01_Red.idat.gz ---- (32/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307597_206402350177_R05C01_Red.idat.gz ---- (33/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307613_206419180144_R02C01_Red.idat.gz ---- (34/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307618_206419180144_R07C01_Red.idat.gz ---- (35/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307594_206402350177_R02C01_Red.idat.gz ---- (36/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307587_206402350163_R03C01_Red.idat.gz ---- (37/38)
#
#   Loading:/home/jovyan/datasets/Cortez_cardoso/idat/GSM8307570_206402350156_R02C01_Red.idat.gz ---- (38/38)
#
#
#   Extract Mean value for Green and Red Channel Success
#
#     Your Red Green Channel contains 1051943 probes.
#
# [ Section 2: Read IDAT Files Done ]
#
#
#
# [ Section 3: Use Annotation Start ]
#
#
#   Reading EPICv1 Annotation >>
#
#
#   Fetching NEGATIVE ControlProbe.
#
#     Totally, there are 411 control probes in Annotation.
#
#     Your data set contains 411 control probes.
#
#
#   Generating Meth and UnMeth Matrix
#
#     Extracting Meth Matrix...
#
#       Totally there are 865918 Meth probes in EPICv1 Annotation.
#
#       Your data set contains 865918 Meth probes.
#
#     Extracting UnMeth Matrix...
#
#       Totally there are 865918 UnMeth probes in EPICv1 Annotation.
#
#       Your data set contains 865918 UnMeth probes.
#
#
#   Generating beta Matrix
#
#   Generating M Matrix
#
#   Generating intensity Matrix
#
#   Calculating Detect P value
#
#   Counting Beads
#
# [ Section 3: Use Annotation Done ]
#
#
# [<<<<< ChAMP.IMPORT END >>>>>>]
#
# [===========================]
#
# [You may want to process champ.filter() next.]
#
#
# [===========================]
#
# [<<<< ChAMP.FILTER START >>>>>]
#
# -----------------------------
#
#
# In New version ChAMP, champ.filter() function has been set to do filtering on the result of champ.import(). You can use champ.import() + champ.filter() to do Data Loading, or set "method" parameter in champ.load() as "ChAMP" to get the same effect.
#
#
# This function is provided for user need to do filtering on some beta (or M) matrix, which contained most filtering system in champ.load except beadcount. User need to input beta matrix, pd file themselves. If you want to do filterintg on detP matrix and Bead Count, you also need to input a detected P matrix and Bead Count information.
#
#
# Note that if you want to filter more data matrix, say beta, M, intensity... please make sure they have exactly the same rownames and colnames.
#
#
#
# [ Section 1:  Check Input Start ]
#
#   You have inputed beta,intensity for Analysis.
#
#
#   pd file provided, checking if it's in accord with Data Matrix...
#
#     pd file check success.
#
#
#   Parameter filterDetP is TRUE, checking if detP in accord with Data Matrix...
#
#     detP check success.
#
#
#   Parameter filterBeads is TRUE, checking if beadcount in accord with Data Matrix...
#
#     beadcount check success.
#
#
#   parameter autoimpute is TRUE. Checking if the conditions are fulfilled...
#
#     !!! ProbeCutoff is 0, which means you have no needs to do imputation. autoimpute has been reset FALSE.
#
#
#   Checking Finished :filterDetP,filterBeads,filterMultiHit,filterSNPs,filterNoCG,filterXY would be done on beta,intensity.
#
#   You also provided :detP,beadcount .
#
# [ Section 1: Check Input Done ]
#
#
#
# [ Section 2: Filtering Start >>
#
#
#   Filtering Detect P value Start
#
#     The fraction of failed positions per sample
#
#     You may need to delete samples with high proportion of failed probes:
#     Failed CpG Fraction.
# S1          0.0006513319
# S2          0.0007702808
# S3          0.0007252419
# S4          0.0011744761
# S5          0.0007518033
# S6          0.0005935897
# S7          0.0015059163
# S8          0.0006293898
# S9          0.0008418811
# S10         0.0008234036
# S11         0.0003891823
# S12         0.0004203631
# S13         0.0013095928
# S14         0.0004561633
# S15         0.0004319116
# S16         0.0004619375
# S17         0.0004203631
# S18         0.0004850344
# S19         0.0005785767
# S20         0.0003776339
# S21         0.0005046667
# S22         0.0007090741
# S23         0.0003741694
# S24         0.0004041953
# S25         0.0003683952
# S26         0.0003533822
# S27         0.0004284470
# S28         0.0004307567
# S29         0.0004884989
# S30         0.0007691259
# S31         0.0028940385
# S32         0.0007598872
# S33         0.0008522747
# S34         0.0006894417
# S35         0.0004030405
# S36         0.0007136934
# S37         0.0007067644
# S38         0.0007633517
#     Filtering probes with a detection p-value above 0.01.
#
#     Removing 5804 probes.
#
#     If a large number of probes have been removed, ChAMP suggests you to identify potentially bad samples
#
#
#   Filtering BeadCount Start
#
#     Filtering probes with a beadcount <3 in at least 5% of samples.
#
#     Removing 12526 probes
#
#
#   Filtering NoCG Start
#
#     Only Keep CpGs, removing 2944 probes from the analysis.
#
#
#   Filtering SNPs Start
#
#     Using general mask options
#
#     Removing 96689 probes from the analysis.
#
#
#   Filtering MultiHit Start
#
#     Filtering probes that align to multiple locations as identified in Nordlund et al
#
#     Removing 3812 probes from the analysis.
#
#
#   Filtering XY Start
#
#     Filtering probes located on X,Y chromosome, removing 16501 probes from the analysis.
#
#
#   Updating PD file
#
#
#   Fixing Outliers Start
#
#     Replacing all value smaller/equal to 0 with smallest positive value.
#
#     Replacing all value greater/equal to 1 with largest value below 1..
#
# [ Section 2: Filtering Done ]
#
#
#  All filterings are Done, now you have 727642 probes and 38 samples.
#
#
# [<<<<< ChAMP.FILTER END >>>>>>]
#
# [===========================]
#
# [You may want to process champ.QC() next.]
#
#
# [<<<<< ChAMP.LOAD END >>>>>>]
#
# [===========================]
#
# [You may want to process champ.QC() next.]
#
#
# [===========================]
#
# [<<<<< ChAMP.QC START >>>>>>]
#
# -----------------------------
#
# champ.QC Results will be saved in ./CHAMP_QCimages/
#
# [QC plots will be proceed with 727642 probes and 38 samples.]
#
#
# << Prepare Data Over. >>
#
# << plot mdsPlot Done. >>
# Plot with title "Beta MDS
# 1000 most variable positions"
# << Plot densityPlot Done. >>
#
#
# < Dendrogram Plot Feature Selection Method >: No Selection, directly use all CpGs to calculate distance matrix.
# Plot with title "Density plot of raw data (727642 probes)"
# << Plot dendrogram Done. >>
#
#
# [<<<<<< ChAMP.QC END >>>>>>>]
#
# [===========================]
#
# [You may want to process champ.norm() next.]
# Plot with title "All samples before normalization (727642 probes)"

# %%
# for two of the normalization methods we need special input, which we generate below
targets <- read.metharray.sheet(data_dir)
rgset <- read.metharray.exp(targets = targets, recursive = TRUE)
mset <- preprocessRaw(rgset)
print("Generation of rgset and mset successfully")
# Out:
# [read.metharray.sheet] Found the following CSV files:
# [1] "/home/jovyan/datasets/Cortez_cardoso/Samplesheet.csv"
# [1] "Generation of rgset and mset successfully"

# %% [markdown]
# #### Peak-based correction normalization (PBC)

# %%
# start with PBC normalization
myNormPBC <- champ.norm(beta = myLoad$beta, arraytype = "EPICv1", method = "PBC")
champ.QC(beta = myNormPBC, pheno = myLoad$pd$Sample_Group, resultsDir = "./CHAMP_QCimages/PBC/")
# Out:
# [===========================]
#
# [>>>>> ChAMP.NORM START <<<<<<]
#
# -----------------------------
#
# champ.norm Results will be saved in ./CHAMP_Normalization/
#
# [ SWAN method call for BOTH rgSet and mset input, FunctionalNormalization call for rgset only , while PBC and BMIQ only needs beta value. Please set parameter correctly. ]
#
#
# << Normalizing data with PBC Method >>
# [1] "Done for sample 1"
# [1] "Done for sample 2"
# [1] "Done for sample 3"
# [1] "Done for sample 4"
# [1] "Done for sample 5"
# [1] "Done for sample 6"
# [1] "Done for sample 7"
# [1] "Done for sample 8"
# [1] "Done for sample 9"
# [1] "Done for sample 10"
# [1] "Done for sample 11"
# [1] "Done for sample 12"
# [1] "Done for sample 13"
# [1] "Done for sample 14"
# [1] "Done for sample 15"
# [1] "Done for sample 16"
# [1] "Done for sample 17"
# [1] "Done for sample 18"
# [1] "Done for sample 19"
# [1] "Done for sample 20"
# [1] "Done for sample 21"
# [1] "Done for sample 22"
# [1] "Done for sample 23"
# [1] "Done for sample 24"
# [1] "Done for sample 25"
# [1] "Done for sample 26"
# [1] "Done for sample 27"
# [1] "Done for sample 28"
# [1] "Done for sample 29"
# [1] "Done for sample 30"
# [1] "Done for sample 31"
# [1] "Done for sample 32"
# [1] "Done for sample 33"
# [1] "Done for sample 34"
# [1] "Done for sample 35"
# [1] "Done for sample 36"
# [1] "Done for sample 37"
# [1] "Done for sample 38"
# [>>>>> ChAMP.NORM END <<<<<<]
#
# [===========================]
#
# [You may want to process champ.SVD() next.]
#
#
# [===========================]
#
# [<<<<< ChAMP.QC START >>>>>>]
#
# -----------------------------
#
# champ.QC Results will be saved in ./CHAMP_QCimages/PBC/
#
# [QC plots will be proceed with 727642 probes and 38 samples.]
#
#
# << Prepare Data Over. >>
#
# << plot mdsPlot Done. >>
# Plot with title "Beta MDS
# 1000 most variable positions"
# << Plot densityPlot Done. >>
#
#
# < Dendrogram Plot Feature Selection Method >: No Selection, directly use all CpGs to calculate distance matrix.
# Plot with title "Density plot of raw data (727642 probes)"
# << Plot dendrogram Done. >>
#
#
# [<<<<<< ChAMP.QC END >>>>>>>]
#
# [===========================]
#
# [You may want to process champ.norm() next.]
# Plot with title "All samples before normalization (727642 probes)"

# %% [markdown]
# #### Beta-mixture quantile normalization (BMIQ)

# %%
# BMIQ normalization
myNormBMIQ <- champ.norm(beta = myLoad$beta, arraytype = "EPICv1", method = "BMIQ", cores=1)
champ.QC(beta = myNormBMIQ, pheno=myLoad$pd$Sample_Group, resultsDir="./CHAMP_QCimages/BMIQ/")
# Out:
# [===========================]
#
# [>>>>> ChAMP.NORM START <<<<<<]
#
# -----------------------------
#
# champ.norm Results will be saved in ./CHAMP_Normalization/
#
# [ SWAN method call for BOTH rgSet and mset input, FunctionalNormalization call for rgset only , while PBC and BMIQ only needs beta value. Please set parameter correctly. ]
#
#
# << Normalizing data with BMIQ Method >>
#
# Note that,BMIQ function may fail for bad quality samples (Samples did not even show beta distribution).
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005077183
# [1] 0.004708642
# [1] 0.005524723
# [1] 0.005706092
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004058496
# [1] 0.001940352
# [1] 0.00249285
# [1] 0.002655579
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S1"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004506169
# [1] 0.003215927
# [1] 0.004270745
# [1] 0.004599777
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004987141
# [1] 0.00246498
# [1] 0.003016145
# [1] 0.003132718
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S2"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004729293
# [1] 0.005053272
# [1] 0.005524231
# [1] 0.005513948
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003706187
# [1] 0.001717993
# [1] 0.002421273
# [1] 0.00275845
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S3"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.006196227
# [1] 0.008141371
# [1] 0.008621067
# [1] 0.008398737
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.005612436
# [1] 0.002213456
# [1] 0.001369417
# [1] 0.001415688
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S4"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005412016
# [1] 0.003890983
# [1] 0.005066686
# [1] 0.005571726
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.00354634
# [1] 0.001248006
# [1] 0.0008286384
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S5"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005405837
# [1] 0.003340261
# [1] 0.004524762
# [1] 0.00494659
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004005093
# [1] 0.002028146
# [1] 0.002430388
# [1] 0.00245826
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S6"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.009290343
# [1] 0.01081394
# [1] 0.01069365
# [1] 0.009974962
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.006767375
# [1] 0.002872464
# [1] 0.001587143
# [1] 0.001157664
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S7"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004806909
# [1] 0.003043793
# [1] 0.003683236
# [1] 0.003798926
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003603624
# [1] 0.002628085
# [1] 0.00280613
# [1] 0.002695701
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S8"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004109383
# [1] 0.003386545
# [1] 0.0039969
# [1] 0.004031346
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003784322
# [1] 0.002069104
# [1] 0.002208285
# [1] 0.002539945
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S9"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004070049
# [1] 0.004237107
# [1] 0.005090987
# [1] 0.005271016
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003546177
# [1] 0.001825105
# [1] 0.002004633
# [1] 0.001898317
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S10"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004653638
# [1] 0.005294046
# [1] 0.005643751
# [1] 0.005570454
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004697038
# [1] 0.001953533
# [1] 0.002108904
# [1] 0.00228956
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S11"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004647243
# [1] 0.005317891
# [1] 0.005940354
# [1] 0.006018466
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003100734
# [1] 0.000892527
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S12"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.008033865
# [1] 0.008708883
# [1] 0.008540354
# [1] 0.00793773
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003071995
# [1] 0.001754552
# [1] 0.00201903
# [1] 0.002014701
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S13"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004196986
# [1] 0.003316903
# [1] 0.004038866
# [1] 0.004114605
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.0043691
# [1] 0.002291965
# [1] 0.002892743
# [1] 0.003103791
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S14"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.003002291
# [1] 0.001335402
# [1] 0.001852809
# [1] 0.001887086
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003414875
# [1] 0.001630015
# [1] 0.002215093
# [1] 0.002640164
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S15"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.0044434
# [1] 0.00429915
# [1] 0.005076252
# [1] 0.005302555
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004298481
# [1] 0.002437633
# [1] 0.002889205
# [1] 0.002957405
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S16"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005073271
# [1] 0.002311311
# [1] 0.003191998
# [1] 0.003577149
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004153771
# [1] 0.002292113
# [1] 0.002690902
# [1] 0.002669629
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S17"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004091066
# [1] 0.003702047
# [1] 0.004649825
# [1] 0.004906225
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.00393532
# [1] 0.002031114
# [1] 0.002384283
# [1] 0.002403925
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S18"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.00540482
# [1] 0.006831332
# [1] 0.007009381
# [1] 0.006630321
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.002816655
# [1] 0.002427046
# [1] 0.002472051
# [1] 0.002244351
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S19"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004666684
# [1] 0.004698974
# [1] 0.005587226
# [1] 0.005857872
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003351736
# [1] 0.00193515
# [1] 0.002360035
# [1] 0.002441198
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S20"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004146182
# [1] 0.004910007
# [1] 0.005370362
# [1] 0.005297784
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003376404
# [1] 0.002542627
# [1] 0.002801577
# [1] 0.002717462
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S21"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004999175
# [1] 0.005417445
# [1] 0.006101963
# [1] 0.006212583
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.00400909
# [1] 0.002580024
# [1] 0.002807681
# [1] 0.002691085
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S22"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004925433
# [1] 0.003945756
# [1] 0.004987266
# [1] 0.005282473
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004255274
# [1] 0.002253417
# [1] 0.00251336
# [1] 0.00243026
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S23"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.00585664
# [1] 0.006360373
# [1] 0.006970761
# [1] 0.007021271
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004331956
# [1] 0.001694792
# [1] 0.002068275
# [1] 0.002320463
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S24"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.0046363
# [1] 0.005995825
# [1] 0.006708876
# [1] 0.006763548
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003020581
# [1] 0.002865786
# [1] 0.00280731
# [1] 0.002462204
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S25"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004891801
# [1] 0.004448991
# [1] 0.005216307
# [1] 0.005390397
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004239516
# [1] 0.002097785
# [1] 0.002544268
# [1] 0.002609696
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S26"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004452896
# [1] 0.005980076
# [1] 0.006740538
# [1] 0.006926655
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003652721
# [1] 0.00193685
# [1] 0.002196865
# [1] 0.002157127
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S27"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005565253
# [1] 0.00331047
# [1] 0.004663674
# [1] 0.00519738
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004193454
# [1] 0.001890605
# [1] 0.002326959
# [1] 0.002377104
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S28"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.003789
# [1] 0.005507249
# [1] 0.006091618
# [1] 0.006031533
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003555015
# [1] 0.001976306
# [1] 0.002212946
# [1] 0.002178322
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S29"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004305789
# [1] 0.0048928
# [1] 0.005751702
# [1] 0.005985084
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003298623
# [1] 0.002278569
# [1] 0.002278271
# [1] 0.002024173
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S30"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.007871218
# [1] 0.009325738
# [1] 0.00875832
# [1] 0.007645519
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.007306892
# [1] 0.003137813
# [1] 0.001520194
# [1] 0.0009998703
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S31"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004827394
# [1] 0.0022195
# [1] 0.003397167
# [1] 0.003909355
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004408986
# [1] 0.001830436
# [1] 0.002352747
# [1] 0.002448435
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S32"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005874485
# [1] 0.006835832
# [1] 0.00717624
# [1] 0.007066221
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004781234
# [1] 0.001842738
# [1] 0.001948509
# [1] 0.001907472
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S33"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004913463
# [1] 0.002556431
# [1] 0.003695158
# [1] 0.00430109
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.004656581
# [1] 0.001773857
# [1] 0.001703501
# [1] 0.001873125
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S34"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005329957
# [1] 0.007449874
# [1] 0.008125194
# [1] 0.008093176
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003322578
# [1] 0.002124121
# [1] 0.00235857
# [1] 0.002309041
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S35"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004655429
# [1] 0.005686187
# [1] 0.006397589
# [1] 0.006473815
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.003687148
# [1] 0.001828133
# [1] 0.002074424
# [1] 0.002022856
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S36"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.005332687
# [1] 0.003738449
# [1] 0.004582271
# [1] 0.004833937
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.00411775
# [1] 0.002108233
# [1] 0.0024822
# [1] 0.002470604
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S37"
# [1] "Fitting EM beta mixture to type1 probes"
# [1] Inf
# [1] 0.004171469
# [1] 0.006130323
# [1] 0.006929459
# [1] 0.007031906
# [1] "Done"
# [1] "Fitting EM beta mixture to type2 probes"
# [1] Inf
# [1] 0.002843875
# [1] 0.002183394
# [1] 0.002344571
# [1] 0.002235051
# [1] "Done"
# [1] "Start normalising type 2 probes"
# [1] "Finished for sample S38"
# [>>>>> ChAMP.NORM END <<<<<<]
#
# [===========================]
#
# [You may want to process champ.SVD() next.]
#
#
# [===========================]
#
# [<<<<< ChAMP.QC START >>>>>>]
#
# -----------------------------
#
# champ.QC Results will be saved in ./CHAMP_QCimages/BMIQ/
#
# [QC plots will be proceed with 727642 probes and 38 samples.]
#
#
# << Prepare Data Over. >>
#
# << plot mdsPlot Done. >>
# Plot with title "Beta MDS
# 1000 most variable positions"
# << Plot densityPlot Done. >>
#
#
# < Dendrogram Plot Feature Selection Method >: No Selection, directly use all CpGs to calculate distance matrix.
# Plot with title "Density plot of raw data (727642 probes)"
# << Plot dendrogram Done. >>
#
#
# [<<<<<< ChAMP.QC END >>>>>>>]
#
# [===========================]
#
# [You may want to process champ.norm() next.]
# Plot with title "All samples before normalization (727642 probes)"

# %% [markdown]
# #### Functional Normalization (FunNorm)

# %%
myNormFunNorm <- champ.norm(beta = myLoad$beta, arraytype = "EPICv1", method = "FunctionalNormalization", rgSet = rgset)
champ.QC(beta = myNormFunNorm, pheno = myLoad$pd$Sample_Group, resultsDir = "./CHAMP_QCimages/FunNorm/")
# Out:
# [===========================]
#
# [>>>>> ChAMP.NORM START <<<<<<]
#
# -----------------------------
#
# champ.norm Results will be saved in ./CHAMP_Normalization/
#
# [ SWAN method call for BOTH rgSet and mset input, FunctionalNormalization call for rgset only , while PBC and BMIQ only needs beta value. Please set parameter correctly. ]
#
#
# [preprocessFunnorm] Background and dye bias correction with noob
#
# [preprocessFunnorm] Mapping to genome
#
# [preprocessFunnorm] Quantile extraction
#
# [preprocessFunnorm] Normalization
#
# [>>>>> ChAMP.NORM END <<<<<<]
#
# [===========================]
#
# [You may want to process champ.SVD() next.]
#
#
# [===========================]
#
# [<<<<< ChAMP.QC START >>>>>>]
#
# -----------------------------
#
# champ.QC Results will be saved in ./CHAMP_QCimages/FunNorm/
#
# [QC plots will be proceed with 727642 probes and 38 samples.]
#
#
# << Prepare Data Over. >>
#
# << plot mdsPlot Done. >>
# Plot with title "Beta MDS
# 1000 most variable positions"
# << Plot densityPlot Done. >>
#
#
# < Dendrogram Plot Feature Selection Method >: No Selection, directly use all CpGs to calculate distance matrix.
# Plot with title "Density plot of raw data (727642 probes)"
# << Plot dendrogram Done. >>
#
#
# [<<<<<< ChAMP.QC END >>>>>>>]
#
# [===========================]
#
# [You may want to process champ.norm() next.]
# Plot with title "All samples before normalization (727642 probes)"

# %%
# save best looking normalization result
myNorm <- myNormBMIQ

# %% [markdown]
# #### Generate a SVD plot that highlights significant differences between groups of samples (Significant differences in the group of interest are good)

# %%
champ.SVD(beta=myNorm, pd=myLoad$pd, resultsDir="./CHAMP_SVDimages/")
SVD_custom(beta=myNorm, filename = "SVD_Wei.pdf")
# Out:
# [===========================]
#
# [<<<<< ChAMP.SVD START >>>>>]
#
# -----------------------------
#
# champ.SVD Results will be saved in ./CHAMP_SVDimages/ .
#
#
# [SVD analysis will be proceed with 727642 probes and 38 samples.]
#
#
#
# [ champ.SVD() will only check the dimensions between data and pd, instead if checking if Sample_Names are correctly matched (because some user may have no Sample_Names in their pd file),thus please make sure your pd file is in accord with your data sets (beta) and (rgSet).]
#
#
# << Following Factors in your pd(sample_sheet.csv) will be analysised: >>
#
# <Sample_ID>(character):GSM8307505, GSM8307507, GSM8307513, GSM8307520, GSM8307521, GSM8307523, GSM8307528, GSM8307533, GSM8307541, GSM8307543, GSM8307506, GSM8307508, GSM8307511, GSM8307514, GSM8307529, GSM8307530, GSM8307531, GSM8307534, GSM8307536, GSM8307547, GSM8307509, GSM8307515, GSM8307516, GSM8307518, GSM8307526, GSM8307553, GSM8307558, GSM8307569, GSM8307572, GSM8307581, GSM8307584, GSM8307586, GSM8307597, GSM8307613, GSM8307618, GSM8307594, GSM8307587, GSM8307570
#
# <Slide>(character):GSM8307505, GSM8307507, GSM8307513, GSM8307520, GSM8307521, GSM8307523, GSM8307528, GSM8307533, GSM8307541, GSM8307543, GSM8307506, GSM8307508, GSM8307511, GSM8307514, GSM8307529, GSM8307530, GSM8307531, GSM8307534, GSM8307536, GSM8307547, GSM8307509, GSM8307515, GSM8307516, GSM8307518, GSM8307526, GSM8307553, GSM8307558, GSM8307569, GSM8307572, GSM8307581, GSM8307584, GSM8307586, GSM8307597, GSM8307613, GSM8307618, GSM8307594, GSM8307587, GSM8307570
#
# <Array>(character):206402350014_R01C01, 206402350014_R03C01, 206402350066_R01C01, 206402350066_R08C01, 206402350102_R01C01, 206402350102_R03C01, 206402350102_R08C01, 206402350127_R05C01, 206402350128_R05C01, 206402350128_R07C01, 206402350014_R02C01, 206402350014_R04C01, 206402350014_R07C01, 206402350066_R02C01, 206402350127_R01C01, 206402350127_R02C01, 206402350127_R03C01, 206402350127_R06C01, 206402350127_R08C01, 206402350151_R03C01, 206402350014_R05C01, 206402350066_R03C01, 206402350066_R04C01, 206402350066_R06C01, 206402350102_R06C01, 206402350152_R01C01, 206402350152_R06C01, 206402350156_R01C01, 206402350156_R04C01, 206402350158_R05C01, 206402350158_R08C01, 206402350163_R02C01, 206402350177_R05C01, 206419180144_R02C01, 206419180144_R07C01, 206402350177_R02C01, 206402350163_R03C01, 206402350156_R02C01
#
# <Sample_Group>(character):old, young
#
# <Sex>(character):F, M
#
# <Age>(integer):76, 69, 77, 71, 66, 70, 65, 67, 68, 74, 72, 49, 50, 48, 53, 46, 44, 51, 45, 56
#
# [champ.SVD have automatically select ALL factors contain at least two different values from your pd(sample_sheet.csv), if you don't want to analysis some of them, please remove them manually from your pd variable then retry champ.SVD().]
#
#
# << Following Factors in your pd(sample_sheet.csv) will not be analysis: >>
#
# <Sample_Plate>
#
# <Sample_Name>
#
# <Project>
#
# <AMP_Plate>
#
# <Sample_Well>
#
# <Scanner>
#
# <Date_Scan>
#
# <Replicate>
#
# <Parent1>
#
# <Parent2>
#
# <Gender>
#
# <Replicate.1>
#
# <Parent1.1>
#
# <Parent2.1>
#
# [Factors are ignored because they only indicate Name or Project, or they contain ONLY ONE value across all Samples.]
#
#
# << PhenoTypes.lv generated successfully. >>
#
# << Calculate SVD matrix successfully. >>
#
# << Plot SVD matrix successfully. >>
#
# [<<<<<< ChAMP.SVD END >>>>>>]
#
# [===========================]
#
# [If the batch effect is not significant, you may want to process champ.DMP() or champ.DMR() or champ.BlockFinder() next, otherwise, you may want to run champ.runCombat() to eliminat batch effect, then rerun champ.SVD() to check corrected result.]
#      Sample_ID Slide     Array     Sample_Group Sex        Age
# [1,] 0.4690744 0.4690744 0.4690744 0.026291395  0.06805059 0.3383690
# [2,] 0.4690744 0.4690744 0.4690744 0.160529535  0.34270745 0.7139823
# [3,] 0.4690744 0.4690744 0.4690744 0.520109982  0.13270256 0.5158668
# [4,] 0.4690744 0.4690744 0.4690744 0.004570807  0.20409478 0.5176653
# [5,] 0.4690744 0.4690744 0.4690744 0.930110508  0.67205901 0.5194203
# [6,] 0.4690744 0.4690744 0.4690744 0.747764881  0.51125691 0.6630776
# [7,] 0.4690744 0.4690744 0.4690744 0.792460089  0.69348574 0.2264667
# [8,] 0.4690744 0.4690744 0.4690744 0.279383679  0.16551786 0.3432491
# [===========================]
#
# [<<<<< ChAMP.SVD START >>>>>]
#
# -----------------------------
#
# champ.SVD Results will be saved in ./CHAMP_SVDimages/ .
#
#
# [SVD analysis will be proceed with 727642 probes and 38 samples.]
#
#
#
# [ champ.SVD() will only check the dimensions between data and pd, instead if checking if Sample_Names are correctly matched (because some user may have no Sample_Names in their pd file),thus please make sure your pd file is in accord with your data sets (beta) and (rgSet).]
#
#
# << Following Factors in your pd(sample_sheet.csv) will be analysised: >>
#
# <Sample_ID>(character):GSM8307505, GSM8307507, GSM8307513, GSM8307520, GSM8307521, GSM8307523, GSM8307528, GSM8307533, GSM8307541, GSM8307543, GSM8307506, GSM8307508, GSM8307511, GSM8307514, GSM8307529, GSM8307530, GSM8307531, GSM8307534, GSM8307536, GSM8307547, GSM8307509, GSM8307515, GSM8307516, GSM8307518, GSM8307526, GSM8307553, GSM8307558, GSM8307569, GSM8307572, GSM8307581, GSM8307584, GSM8307586, GSM8307597, GSM8307613, GSM8307618, GSM8307594, GSM8307587, GSM8307570
#
# <Slide>(character):GSM8307505, GSM8307507, GSM8307513, GSM8307520, GSM8307521, GSM8307523, GSM8307528, GSM8307533, GSM8307541, GSM8307543, GSM8307506, GSM8307508, GSM8307511, GSM8307514, GSM8307529, GSM8307530, GSM8307531, GSM8307534, GSM8307536, GSM8307547, GSM8307509, GSM8307515, GSM8307516, GSM8307518, GSM8307526, GSM8307553, GSM8307558, GSM8307569, GSM8307572, GSM8307581, GSM8307584, GSM8307586, GSM8307597, GSM8307613, GSM8307618, GSM8307594, GSM8307587, GSM8307570
#
# <Array>(character):206402350014_R01C01, 206402350014_R03C01, 206402350066_R01C01, 206402350066_R08C01, 206402350102_R01C01, 206402350102_R03C01, 206402350102_R08C01, 206402350127_R05C01, 206402350128_R05C01, 206402350128_R07C01, 206402350014_R02C01, 206402350014_R04C01, 206402350014_R07C01, 206402350066_R02C01, 206402350127_R01C01, 206402350127_R02C01, 206402350127_R03C01, 206402350127_R06C01, 206402350127_R08C01, 206402350151_R03C01, 206402350014_R05C01, 206402350066_R03C01, 206402350066_R04C01, 206402350066_R06C01, 206402350102_R06C01, 206402350152_R01C01, 206402350152_R06C01, 206402350156_R01C01, 206402350156_R04C01, 206402350158_R05C01, 206402350158_R08C01, 206402350163_R02C01, 206402350177_R05C01, 206419180144_R02C01, 206419180144_R07C01, 206402350177_R02C01, 206402350163_R03C01, 206402350156_R02C01
#
# <Sample_Group>(character):old, young
#
# <Sex>(character):F, M
#
# <Age>(integer):76, 69, 77, 71, 66, 70, 65, 67, 68, 74, 72, 49, 50, 48, 53, 46, 44, 51, 45, 56
#
# [champ.SVD have automatically select ALL factors contain at least two different values from your pd(sample_sheet.csv), if you don't want to analysis some of them, please remove them manually from your pd variable then retry champ.SVD().]
#
#
# << Following Factors in your pd(sample_sheet.csv) will not be analysis: >>
#
# <Sample_Plate>
#
# <Sample_Name>
#
# <Project>
#
# <AMP_Plate>
#
# <Sample_Well>
#
# <Scanner>
#
# <Date_Scan>
#
# <Replicate>
#
# <Parent1>
#
# <Parent2>
#
# <Gender>
#
# <Replicate.1>
#
# <Parent1.1>
#
# <Parent2.1>
#
# [Factors are ignored because they only indicate Name or Project, or they contain ONLY ONE value across all Samples.]
#
#
# << PhenoTypes.lv generated successfully. >>
#
# << Calculate SVD matrix successfully. >>
#
# << Plot SVD matrix successfully. >>
#
# [<<<<<< ChAMP.SVD END >>>>>>]
#
# [===========================]
#
# [If the batch effect is not significant, you may want to process champ.DMP() or champ.DMR() or champ.BlockFinder() next, otherwise, you may want to run champ.runCombat() to eliminat batch effect, then rerun champ.SVD() to check corrected result.]
#      Sample_ID Slide     Array     Sample_Group Sex        Age
# [1,] 0.4690744 0.4690744 0.4690744 0.026291395  0.06805059 0.3383690
# [2,] 0.4690744 0.4690744 0.4690744 0.160529535  0.34270745 0.7139823
# [3,] 0.4690744 0.4690744 0.4690744 0.520109982  0.13270256 0.5158668
# [4,] 0.4690744 0.4690744 0.4690744 0.004570807  0.20409478 0.5176653
# [5,] 0.4690744 0.4690744 0.4690744 0.930110508  0.67205901 0.5194203
# [6,] 0.4690744 0.4690744 0.4690744 0.747764881  0.51125691 0.6630776
# [7,] 0.4690744 0.4690744 0.4690744 0.792460089  0.69348574 0.2264667
# [8,] 0.4690744 0.4690744 0.4690744 0.279383679  0.16551786 0.3432491
# Plot with title "Singular Value Decomposition Analysis (SVD)"

# %% [markdown]
# #### Calculate Differentially Methylated Probes (DMPs) between Samplegroups

# %%
DMPs <- champ.DMP(beta = myNorm,pheno=myLoad$pd$Sample_Group, adjPVal = 0.05, arraytype = "EPICv1")
saveRDS(DMPs, file = "/home/jovyan/myDMP.rds")
saveRDS(myNorm, file = "/home/jovyan/myNorm.rds")
saveRDS(myLoad, file = "/home/jovyan/myLoad.rds")
print("DMP detection completed")
# Out:
# [===========================]
#
# [<<<<< ChAMP.DMP START >>>>>]
#
# -----------------------------
#
# !!! Important !!! New Modification has been made on champ.DMP():
#
#
#     (1): In this version champ.DMP() if your pheno parameter contains more than two groups of phenotypes, champ.DMP() would do pairewise differential methylated analysis between each pair of them. But you can also specify compare.group to only do comparasion between any two of them.
#
#
#     (2): champ.DMP() now support numeric as pheno, and will do linear regression on them. So covariates like age could be inputted in this function. You need to make sure your inputted "pheno" parameter is "numeric" type.
#
#
# --------------------------------
#
#
# [ Section 1:  Check Input Pheno Start ]
#
#
#   You pheno is character type.
#
#     Your pheno information contains following groups. >>
#
#     <old>:20 samples.
#
#     <young>:18 samples.
#
#     [The power of statistics analysis on groups contain very few samples may not strong.]
#
#     pheno contains only 2 phenotypes
#
#     compare.group parameter is NULL, two pheno types will be added into Compare List.
#
#     old_to_young compare group : old, young
#
#
# [ Section 1:  Check Input Pheno Done ]
#
#
#
# [ Section 2:  Find Differential Methylated CpGs Start ]
#
#
#   -----------------------------
#
#   Start to Compare : old, young
#
#   Contrast Matrix
#         Contrasts
# Levels   pyoung-pold
#   pold            -1
#   pyoung           1
#   You have found 3 significant MVPs with a BH adjusted P-value below 0.05.
#
#   Calculate DMP for old and young done.
#
#
# [ Section 2:  Find Numeric Vector Related CpGs Done ]
#
#
#
# [ Section 3:  Match Annotation Start ]
#
#
#
# [ Section 3:  Match Annotation Done ]
#
#
# [<<<<<< ChAMP.DMP END >>>>>>]
#
# [===========================]
#
# [You may want to process DMP.GUI() or champ.GSEA() next.]
# [1] "DMP detection completed"

# %% [markdown]
# #### Visualize and explore the calculated DMPs

# %%
urls <- paste0("https://methylomemasterclass202609.jhaas.gi.denbi.de/user/", Sys.getenv("JUPYTERHUB_USER"), "/shiny/notebooks/App/DMP.GUI/")
cli::cli_text("Click here for interactive exploration of DMPs: {urls}.")

# %%
DMRs <- champ.DMR(beta=myNorm,pheno=myLoad$pd$Sample_Group,method="Bumphunter", arraytype="EPICv1", cores=1)
saveRDS(DMRs, "/home/jovyan/myDMR.rds")
print("DMR detection completed")
# Out:
# [===========================]
#
# [<<<<< ChAMP.DMR START >>>>>]
#
# -----------------------------
#
# !!! important !!! We just upgrate champ.DMR() function, since now champ.DMP() could works on multiple phenotypes, but ProbeLasso can only works on one DMP result, so if your pheno parameter contains more than 2 phenotypes, and you want to use ProbeLasso function, you MUST specify compare.group=c("A","B"). Bumphunter and DMRcate should not be influenced.
#
#
# [ Section 1:  Check Input Pheno Start ]
#
#
#   You pheno is character type.
#
#     Your pheno information contains following groups. >>
#
#     <old>:20 samples.
#
#     <young>:18 samples.
#
#
# [ Section 1:  Check Input Pheno Done ]
#
#
#
# [ Section 2:  Run DMR Algorithm Start ]
#
#
# << Find DMR with Bumphunter Method >>
#
# 1 cores will be used to do parallel Bumphunter computing.
#
# According to your data set, champ.DMR() detected 10190 clusters contains MORE THAN 7 probes within 300 maxGap. These clusters will be used to find DMR.
#
#
# [bumphunterEngine] Using a single core (backend: doParallelMC, version: 1.0.17).
#
# [bumphunterEngine] Computing coefficients.
#
# [bumphunterEngine] Smoothing coefficients.
#
# Warning message in foreach(idx = iter(IndexesChunks), .packages = "bumphunter") %dorng% :
# "Foreach loop (doParallelMC) had changed the current RNG type: RNG was restored to same type, next state"
# [bumphunterEngine] Performing 250 bootstraps.
#
# Warning message in foreach(bootstraps = iter(bootIndexes, by = "column", chunksize = chunksize), :
# "Foreach loop (doParallelMC) had changed the current RNG type: RNG was restored to same type, next state"
# [bumphunterEngine] Computing marginal bootstrap p-values.
#
# [bumphunterEngine] Smoothing bootstrap coefficients.
#
# Warning message in foreach(idx = iter(IndexesChunks), .packages = "bumphunter") %dorng% :
# "Foreach loop (doParallelMC) had changed the current RNG type: RNG was restored to same type, next state"
# [bumphunterEngine] cutoff: 0.554
#
# [bumphunterEngine] Finding regions.
#
# [bumphunterEngine] Found 1481 bumps.
#
# [bumphunterEngine] Computing regions for each bootstrap.
#
# Warning message in foreach(subMat = iter(permBeta, by = "col", chunksize = chunksize), :
# "Foreach loop (doParallelMC) had changed the current RNG type: RNG was restored to same type, next state"
# [bumphunterEngine] Estimating p-values and FWER.
#
# Warning message in foreach(subL = iter(Lvalue, by = "row", chunksize = chunksize), :
# "Foreach loop (doParallelMC) had changed the current RNG type: RNG was restored to same type, next state"
# Warning message in foreach(subA = iter(Avalue, by = "row", chunksize = chunksize), :
# "Foreach loop (doParallelMC) had changed the current RNG type: RNG was restored to same type, next state"
# << Calculate DMR success. >>
#
# Bumphunter detected 201 DMRs with P value <= 0.05.
#
#
# [ Section 2:  Run DMR Algorithm Done ]
#
#
# [<<<<<< ChAMP.DMR END >>>>>>]
#
# [===========================]
#
# [You may want to process DMR.GUI() or champ.GSEA() next.]
# [1] "DMR detection completed"

# %% [markdown]
# #### Visualize and explore the calculated DMRs

# %%
urls <- paste0("https://methylomemasterclass202609.jhaas.gi.denbi.de/user/", Sys.getenv("JUPYTERHUB_USER"), "/shiny/notebooks/App/DMR.GUIepicv1/")
cli::cli_text("Click here for interactive exploration of DMRs: {urls}.")
# Out:
# Click here for interactive exploration of DMRs:
# https://methylomemasterclass202609.jhaas.gi.denbi.de/user/9e112b87-20f5-4aec-869e-4dfb60de4beb/shiny/notebooks/App/DMR.GUIepicv1/.

# %% [markdown]
# #### Filter the calculated DMRs for significance

# %%
anno <- getAnnotation(IlluminaHumanMethylationEPICanno.ilm10b4.hg19)
DMRs_filt <- filter_dmrs(DMRs$BumphunterDMR, pval = 0.05, fwer = 0.05,min_abs_value = 0.5)
DMRs_anno <- annotateDMRs(DMRs_filt, anno = anno, myNorm = myNorm)
DMRs_head <- DMRs_anno[1:min(c(nrow(DMRs_anno), 10)), ]
print(DMRs_head)
DMRs_tail <- DMRs_anno[max(c(0,(nrow(DMRs_anno)-9))):nrow(DMRs_anno), ]
# Out:
# DMR 1 annotiert: 31 CpGs gefunden.
# DMR 2 annotiert: 21 CpGs gefunden.
# DMR 3 annotiert: 19 CpGs gefunden.
# DMR 4 annotiert: 27 CpGs gefunden.
#       seqnames    start      end width strand      value     area cluster
# DMR_1     chr6 29521013 29521803   790      * -1.5653971 48.52731  360658
# DMR_2     chr6 33244715 33245585   870      * -1.2238471 25.70079  362315
# DMR_4    chr12 95941571 95943131  1560      * -1.0771014 20.46493  104110
# DMR_3    chr18 74960996 74962369  1373      * -0.9460126 25.54234  201572
#       indexStart indexEnd  L clusterL      p.value  fwer  p.valueArea fwerArea
# DMR_1      97066    97096 31       35 0.000000e+00 0.000 0.0000000000    0.000
# DMR_2     101481   101501 21       46 8.507959e-06 0.004 0.0001106035    0.040
# DMR_4      29025    29043 19       19 4.253980e-05 0.016 0.0003573343    0.132
# DMR_3      56328    56354 27       30 3.403184e-05 0.016 0.0001106035    0.040
#       n_CpGs
# DMR_1     31
# DMR_2     21
# DMR_4     19
# DMR_3     27
#                                                                                                                                                                                                                                                                                                                                                       CpGs
# DMR_1 cg21153898;cg26131286;cg21133153;cg13641185;cg21632158;cg19690984;cg00674706;cg00370229;cg22305167;cg02149189;cg20034792;cg15814717;cg15818307;cg12217400;cg22762215;cg22617773;cg06613392;cg15490715;cg10491628;cg14278853;cg18342026;cg21834061;cg16044251;cg06087185;cg03409187;cg27546977;cg12749246;cg20723129;cg26142965;cg06343355;cg09205920
# DMR_2                                                                                                               cg21333861;cg06753439;cg03108070;cg27098900;cg21387418;cg16396284;cg03189210;cg05973866;cg26381352;cg13365340;cg19664267;cg15543281;cg11772919;cg04263436;cg19241689;cg26270195;cg17416730;cg19156220;cg10633838;cg11626629;cg04262471
# DMR_4                                                                                                                                     cg25767001;cg13879483;cg03918605;cg03308628;cg10431993;cg22802813;cg12701184;cg00256076;cg22538054;cg09883286;cg08571241;cg01123334;cg26438317;cg03162823;cg17368254;cg23982858;cg00927554;cg24587879;cg07783282
# DMR_3                                             cg21938435;cg03175653;cg20872937;cg15146859;cg26065057;cg04534765;cg25165358;cg17911318;cg21634365;cg03659519;cg06562865;cg26721264;cg10122698;cg01178451;cg00854242;cg19056926;cg18461021;cg03032214;cg19705131;cg10486998;cg15343119;cg21661027;cg07390210;cg15484988;cg12699371;cg05528293;cg18961944
#         Genes                RefGene_Group
# DMR_1    <NA>                         <NA>
# DMR_2 B3GALT4 1stExon;5'UTR;TSS200;TSS1500
# DMR_4   USP44         TSS200;5'UTR;TSS1500
# DMR_3   GALR1 5'UTR;1stExon;TSS1500;TSS200

# %% [markdown]
# #### Plot heatmaps for the filtered DMRs
# You can use this section in combination with the DMR or DMP GUIs to visualize methylation across samples for genes of interest.

# %%
makeHeatmap_genelist(pdfname = "./Heatmap_images/heatmap_Cortez_Cardoso_genelist.pdf",
                            anno = anno,
                            genelist = c("NPY", "RASSF1", "CLDN10"),
                            myNorm = myNorm,
                            targets = targets,
                            pd_col = "Sample_Group",
                            compare_values = c("old", "young"))

makeHeatmap_dmr(pdfname = "./Heatmap_images/heatmap_Cortez_Cardoso_dmrs_hypermethylated.pdf",
                dmrs = DMRs_head,
                anno = anno,
                myNorm = myNorm,
                targets = targets,
                pd_col = "Sample_Group",
                compare_values = c("old", "young"))

makeHeatmap_dmr(pdfname = "./Heatmap_images/heatmap_Cortez_Cardoso_dmrs_hypomethylated.pdf",
                dmrs = DMRs_tail,
                anno = anno,
                myNorm = myNorm,
                targets = targets,
                pd_col = "Sample_Group",
                compare_values = c("old", "young"))
# Out:
# Starte Heatmap für NPY
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für RASSF1
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für CLDN10
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# agg_record_546353173
#                    2
# Starte Heatmap für DMR 1
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für DMR 2
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für DMR 3
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für DMR 4
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# agg_record_546353173
#                    2
# Starte Heatmap für DMR 1
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für DMR 2
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für DMR 3
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# Starte Heatmap für DMR 4
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# "conversion failure on 'β-Wert' in 'mbcsToSbcs': for β (U+03B2)"
# agg_record_546353173
#                    2
